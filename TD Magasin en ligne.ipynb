# %% [markdown]
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1AsKm6Gzjuvqp9RmXxjTHdbTr4eo7kHsp" width="130" align="left"/> </html>
# <h6>Faculté des Sciences de Monastir </h6>
# <h6>Département des Sciences de l’Informatique </h6>
# <h6>Informatique des Classes Préparatoires:  <b>MP1/PC1</b></h6>
# <h6>Enseignant: Jaafar CHAAOURI </h6>

# %% [markdown]
# <img src='https://docs.google.com/uc?export=download&id=1BmLEthy7KCNsnVFviFKX77zLmFhc47XZ' align='right'/>
#
# <center> <H1>  <b></b></H1> </center> <center> <H1> </center> </H1>

# %% [markdown]
# **Exercice 1: Chiffrement de fichiers:**

# %% [markdown]
# Chiffrer un message revient à le transformer en le rendant illisible. Seul le destinataire du message peut le faire revenir à sa forme initiale.
#
# L'objectif de cet exercice est de réaliser une fonction Python permettant de chiffrer le contenu d'un fichier texte en utilisant la méthode suivante:
#
# **<u>Etape 1 :</u>**
#
# - Soient deux fichiers textes : un fichier "**cle.txt**" et un fichier "**message.txt**"
# - supposons que le fichier cle.txt est suffisament long de sorte qu'il contient suffisament de caractère pour former le fichier message.txt
#
# **<u>Etape 2 :</u>** Construire un dictionnaire **D** dont :
#
# - la clé : une lettre **c** du fichir "**cle.txt**"
# - la valeur : un ensemble (**set**) regroupant les différentes positions d'apparition de la clé dans le fichier "**cle.txt**"
# - Exemple : Pour le fichier cle.txt
#
#     *- Bonjour tout le monde!*
#     - Nous obtenons le dictionnaire :
#
#
#
# > `D = { 'B':{0}, 'o':{1,4,9,17}, 'n':{2,18}, 'j':{3}, 'u':{10,5}, 'r':{6}, '':{12,15,7}, 't':{8,11}, 'l':{13}, 'e':{20,14}, 'm':{16},
# 'd':{19}, '!':{21}} `

# %% [markdown]
# **<u>Etape 3 :</u>**
# - Transformons le contenu du fichier "**message.txt**" en <u><b> remplaçant chaque lettre c</b></u> du fichier par la lettre cchif obtenue comme suit :
#     - Soit **S** = l'ensemble associé à la clé **c** dans le dictionnaire **D**
#     - Calculer **N=min(S)**
#     - **cchif = chr(N)** c-à-d la lettre ayant comme code la valeur **N**
#     - Supprimer la valeur **N** de **S**

# %% [markdown]
# **<u>Etape 4 :</u>**  Enregistrer le message chiffré dans le fichier "**resultat.txt**"

# %% [markdown]
# **indication :** la méthode chr est prédéfinie en Python

# %% [markdown]
# **<u>Travail à faire</u>** :
# 1. Ecrire une fonction Python **ContruireDict()** qui retourne le dictionnaire **D** selon la desciption ci-dessus.

# %% [markdown]
# 2. Ecrire une fonction **<u>récursive</u>** **Transformer(ch,D)** qui prend en paramètre une chaine de caractères ch et un dictionnaire D (dont le contenu respecte l'étape 2) et retourne la chaine chiffrée correspondante.

# %% [markdown]
# 3. Ecrire une fonction Python **Chiffrer()** qui permet de transformer le contenu du fichier "**message.txt**" selon la méthode décrite ci-deesus et d'enregistrer le message chiffré dans le fichier "**resultat.txt**".

# %% [markdown]
# **Problème 1: Magasin en ligne**

# %% [markdown]
# L’objectif de ce problème est de gérer un ensemble de produits dans un magasin de vente de console de jeux. La base de données des produits est représentée en Python par un
# dictionnaire Produits. Un produit est représenté par les informations suivantes :
# - **nom**: le nom du produit, de type str, qui représente la clé du dictionnaire
# - **(prix, quantité)** : un tuple qui présente une valeur associée à une clé : prix, de type
# float, représente le prix unitaire du produit et quantité, de type int, représente la
# quantité disponible en stock de ce produit.
#
# Exemple :
# ```
# Produits= {'Playstation 4' : (1600.0, 12),  'Nintendo DS' : (1459.5, 10),  'Atari' : (558.5, 0), 'Xbox' : (1120.0,5)}
# ```
#
# Le dictionnaire Produits est défini comme une variable globale.

# %% [markdown]
# **Q1**: Ecrire la fonction **AjoutProduit** qui prend comme paramètre le nom du produit **prod**, son prix unitaire **prix**, et la quantité disponible **quantite**, et l’ajoute au dictionnaire **Produits**.
# ```
# Par exemple : AjoutProduit ('My Arcade', 122.0, 20)
# ```

# %% [markdown]
# **Q2** :Ecrire la fonction **disponibilite** qui étant donné un nom de produit **prod**, retourne **True** si le produit est présent dans le dictionnaire avec une quantité strictement positif, ou **False** sinon.
# ```
# Exemple :
# disponibilite ('Atari') => False ;
# disponibilite('Xbox') => True ;
# disponibilite ('PS3') => False
# ```

# %% [markdown]
# **Q3** : Ecrire la fonction **prix_moyen** qui retourne le prix unitaire moyen des produits disponibles dans le dictionnaire de produits.
# Exemple : prix_moyen() => 1184.5, car (1600.0+1459.5+558.5+1120.0)/4

# %% [markdown]
# **Q4** :
# Ecrire la fonction **fourchette_prix** qui, étant donné un prix minimum **mini**, un prix maximum **maxi**, retourne la liste des noms de produits disponibles dans cette fourchette de prix.
#
#
# ```
# Exemple : fourchette_prix(800.0,1500.0) => ['Nintendo DS', 'Xbox']
# ```

# %% [markdown]
# **Q5** : Le panier est un concept omniprésent dans les sites marchands. En Python, le panier du client sera représenté par un dictionnaire avec :
# les noms des produits comme clés
# une quantité d’achat comme valeurs associées.
#
# Par exemple: **Panier** = {'Playstation 4' : 1, 'Nintendo DS' : 3, 'Xbox' : 2}
#
# Ecrire la fonction **tous_disponibles** qui, étant donné un panier d’achat **Panier**, retourne True si tous les produits demandés sont disponibles dans le dictionnaire de produits avec les quantités demandées, ou False sinon.
# ```
# Exemple :
# pour Panier = {'Playstation 4' : 1 , 'Nintendo DS' : 3 , 'Xbox' : 2} tous_disponibles (Panier) => True
# pour Panier = {'Playstation 4' : 1, 'Xbox' : 6} tous_disponibles (Panier) => False
# ```

# %% [markdown]
# **Q6** : Ecrire la fonction **prix_achats** qui, étant donné un panier d’achat **Panier**, retourne le prix total correspondant. On supposera que tous les articles du panier sont disponibles dans la base de produits.
# ```
# Exemple :
# pour Panier = {'Playstation 4' : 1 , 'Nintendo DS' : 3 , 'Xbox' : 2}
# prix_achats (Panier) => 8218.5
#
# ```

# %% [markdown]
# **Problème 2: Agenda**

# %% [markdown]
# L’objectif de ce problème est de gérer un ensemble de rendez-vous, qui forment l’agenda d’une personne. Un rendez-vous est représenté par les informations suivantes :
# - la date **date**, représentée par une chaîne de caractères (sous la forme
# "jj/mm/aaaa")
# - l’heure, **heure**, représentée par un entier
# - le nom, **nom** de la personne avec qui on a rendez-vous, représenté par une chaîne de caractères.
#
# (on suppose que tous les rendez-vous ont lieu à une heure pile, par exemple 10h sera représenté par l’entier 10)
#
# ```
# Exemple :
# Agenda = { ('17/01/2019', 10, 'Ali'), ('17/01/2019', 11, 'Karim'), ('18/01/2019', 10, 'Salah'),
# ('19/01/2019', 10, 'Mohamed'), ('19/01/2019', 14, 'Salah') }
# ```

# %% [markdown]
# **Q1** : Donner une définition de la fonction **remplir_Agenda** qui permet de remplir et retourner l’ensemble E des rendez-vous, les données seront saisies par l’utilisateur.
# ```
# Exemple d’exécution pour la saisie des données:
#
# >>> Agenda=remplir_Agenda()
#
# *** RDV 1 ***
# Entrer la date : 17/01/2019
# Entrer l'heure :10
# Entrer le nom : Ali
# Voulez-vous ajouter d'autre éléments O/N: o # la saisie des rendez-vous continue si on répond par 'o'
# *** RDV 2 ***
# Entrer la date : 17/01/2019
# Entrer l'heure :11
# Entrer le nom : Karim
# Voulez-vous ajouter d'autre éléments O/N: n # la saisie des rendez-vous se termine si on répond par 'n'
# ```

# %% [markdown]
# **Q2** : Donner une définition de la fonction **rdv_personne** qui, étant donné un ensemble de rendez-vous E et une chaîne nom représentant le nom d’une personne, renvoie l’ensemble des rendez-vous avec cette personne.
# ```
# Exemple d’exécution :
# >>> print (rdv_personne(Agenda, 'Salah'))
# {('18/01/2015', 10, 'Salah'), ('19/11/2015', 14, 'Salah')}
# ```

# %% [markdown]
# **Q3** :Donner une définition de la fonction **rdv_restants** qui, étant donné un ensemble de rendez-vous E, une date d et une heure h, renvoie l’ensemble des rendez-vous de E qui auront lieu à la
# date d et après l’heure h.
# ```
# Exemple d’exécution :
# >>> print (rdv_restants (Agenda, '19/01/2019' , 9))
# {('19/01/2019', 10, 'Mohamed'), ('19/01/2019', 14, 'Salah')}
# ```

# %% [markdown]
# **Q4** :Donner une définition de la fonction **dict_rdv** qui, étant donné un ensemble de rendez-vous
# **E**, renvoie un dictionnaire associant à chaque date de E le nombre de rendez-vous ayant lieu
# à cette date.
# ```
# Exemple d’exécution :
# >>> print(dict_rdv (Agenda))
# {'18/01/2019': 1, '19/01/2019': 2, '17/01/2019': 2}
# ```

# %% [markdown]
# **Q5** : Donner une définition de la fonction **dict_date** qui, étant donné un ensemble de rendez-vous **E**, renvoie un dictionnaire dont :
# - les clés sont les dates des rendez-vous de E.
# - La valeur correspondante à chaque dat, est la liste de couples (h, p) pour chaque rendez-vous (d, h, p) de E.
# ```
# Exemple d’exécution :
# >>> print(dict_date (Agenda))
# {'19/01/2019': [(10, 'Mohamed'), (14, 'Salah')],
# '17/01/2019': [(11, 'Karim'), (10, 'Ali')],'18/01/2019': [(10, 'Salah')]}
# ```

# %% [markdown]
# **Q6** :
# Donner une définition de la fonction **conflit_rdv** qui, étant donnés deux rendez-vous **r** et **s**, renvoie :
# - True si les deux rendez-vous ont lieu à la même date et à la même heure, et
# - False sinon.
# ```
# Exemple d’exécution :
# >>> conflit_rdv(('18/02/2019', 10, 'Mohamed'), ('18/02/2019', 10, 'Rami') )
# True
# >>>conflit_rdv(('18/02/2019', 10, 'Mohamed'), ('18/02/2019', 11, 'Rami') )
# False
# ```

# %% [markdown]
# **Q7** : Donner une définition de la fonction **conflit_agenda** qui, étant donné un ensemble de rendez-vous E, renvoie True si E contient deux rendez-vous qui sont en conflit, et False
# sinon.
# ```
# Exemple :
# Si Agenda = { ('17/01/2019', 10, 'Ali'), ('17/01/2019', 11, 'Karim'),
# ('18/01/2019', 10, 'Salah'), ('19/01/2019', 10, 'Mohamed'), ('19/01/2019', 14, 'Salah') }
#
# >>> conflit_agenda(Agenda)
# False
#
# Si Agenda = { ('17/01/2019', 10, 'Ali'), ('17/01/2019', 11, 'Karim'),
# ('18/01/2019', 10, 'Salah'), ('19/01/2019', 10, 'Mohamed'),
# ('19/01/2019', 10, 'Salah') }
# >>> conflit_agenda(Agenda)
# True
# ```
